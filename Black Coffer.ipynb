# %%
import requests
from bs4 import BeautifulSoup
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import word_tokenize
from collections import Counter
import re
import nltk

# Download the necessary NLTK resources
nltk.download('vader_lexicon')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vsgha\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vsgha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def get_article_text(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    for script in soup(["script", "style"]):
        script.extract()

    text = soup.get_text()
    text = re.sub(r'\s+', ' ', text)  # Remove extra whitespaces
    return text.strip()

# %%
def load_words_from_txt(file_name, encoding='utf-8'):
    with open(file_name, 'r', encoding=encoding, errors='ignore') as file:
        words = set(file.read().splitlines())
    return words

# %%
def calculate_complexity(text):
    sentences = sent_tokenize(text)
    words = word_tokenize(text)
    syllables = [sum(1 for char in word if char.lower() in 'aeiouy') for word in words]

    return {
        'average_sentence_length': len(words) / len(sentences),
        'percentage_of_complex_words': (len([word for word in words if len(word) > 7]) / len(words)) * 100,
        'fog_index': 0.4 * (100 * len(words) / len(sentences) + 100 * sum(syllables) / len(words)) / 2,
        'average_number_of_words_per_sentence': len(words) / len(sentences),
        'complex_word_count': len([word for word in words if len(word) > 7]),
        'word_count': len(words),
        'syllable_per_word': sum(syllables) / len(words),
        'average_word_length': len(text) / len(words),
    }

# %%
def analyze_sentiment(text, positive_words, negative_words):
    sia = SentimentIntensityAnalyzer()
    sentences = sent_tokenize(text)
    sentiment_scores = []

    for sentence in sentences:
        score = sia.polarity_scores(sentence)
        sentiment_score = score['pos'] - score['neg']
        sentiment_scores.append(sentiment_score)

    # Calculate overall sentiment scores
    total_sentiment_score = sum(sentiment_scores)
    positive_score = sum(max(0, score) for score in sentiment_scores)
    negative_score = -sum(min(0, score) for score in sentiment_scores)

    # Calculate subjectivity score
    subjectivity_score = sia.polarity_scores(text)['neu']

    return {
        'polarity_score': total_sentiment_score,
        'positive_score': positive_score,
        'negative_score': negative_score,
        'subjectivity_score': subjectivity_score,
    }

# %%
def extract_personal_pronouns(text):
    pronouns = ['i', 'you', 'he', 'she', 'it', 'we', 'they', 'me', 'him', 'her', 'its', 'us', 'them', 'my', 'your', 'his', 'her', 'its', 'our', 'their']
    words = word_tokenize(text)
    return Counter([word for word in words if word.lower() in pronouns])

# %%
input_urls = [
    'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/',
    'https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/',
    'https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/',
    'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/',
    'https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/',
    'https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/',
    'https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/',
    'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/',
    'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/',
    'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/',
    'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/',
    'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/',
    'https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/',
    'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/',
    'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/',
    'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/',
    'https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/',
    'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/',
    'https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/',
    'https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/',
    'https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/',
    'https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/',
    'https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/',
    'https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/',
    'https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/',
    'https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/',
    'https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/',
    'https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/',
    'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/',
    'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/',
    'https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/',
    'https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/',
    'https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/',
    'https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/',
    'https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/',
    'https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/',
    'https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/',
    'https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/',
    'https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/',
    'https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/',
    'https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/',
    'https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/',
    'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/',
    'https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/',
    'https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/',
    'https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/',
    'https://insights.blackcoffer.com/evolution-of-advertising-industry/',
    'https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/',
    'https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/',
    'https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/',
    'https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/',
    'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/',
    'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/',
    'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/',
    'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/',
    'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/',
    'https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/',
    'https://insights.blackcoffer.com/how-we-forecast-future-technologies/',
    'https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/',
    'https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/',
    'https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/',
    'https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/',
    'https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/',
    'https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/',
    'https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/',
    'https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/',
    'https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/',
    'https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/',
    'https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/',
    'https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/',
    'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/',
    'https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/',
    'https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/',
    'https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/',
    'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/',
    'https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/',
    'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/',
    'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/',
    'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/',
    'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/',
    'https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/',
    'https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/',
    'https://insights.blackcoffer.com/human-rights-outlook/',
    'https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/',
    'https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/',
    'https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/',
    'https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/',
    'https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/',
    'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/',
    'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/',
    'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/',
    'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/',
    'https://insights.blackcoffer.com/travel-and-tourism-outlook/',
    'https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/',
    'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/',
    'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/',
    'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/',
    'https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/',
    'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/',
    'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'

]

# %%
positive_words = load_words_from_txt('positive-words.txt', encoding='latin-1')
negative_words = load_words_from_txt('negative-words.txt', encoding='latin-1')

# %%
for url in input_urls:
    text = get_article_text(url)
    complexity = calculate_complexity(text)
    sentiment = analyze_sentiment(text, positive_words, negative_words)
    personal_pronouns = extract_personal_pronouns(text)

    print('URL:', url)
    print('Complexity:', complexity)
    print('Sentiment:', sentiment)

    # Print total personal pronouns count for the current URL
    print('Total Personal Pronouns:', sum(personal_pronouns.values()))

    print('\n' + '='*50 + '\n')  # Separator for better readability
# Out:
# URL: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# Complexity: {'average_sentence_length': 26.795698924731184, 'percentage_of_complex_words': 17.49598715890851, 'fog_index': 572.374652651927, 'average_number_of_words_per_sentence': 26.795698924731184, 'complex_word_count': 436, 'word_count': 2492, 'syllable_per_word': 1.8230337078651686, 'average_word_length': 5.583868378812199}
# Sentiment: {'polarity_score': 11.273999999999997, 'positive_score': 12.171999999999999, 'negative_score': 0.898, 'subjectivity_score': 0.854}
# Total Personal Pronouns: 138
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# Complexity: {'average_sentence_length': 29.40625, 'percentage_of_complex_words': 21.96245129295076, 'fog_index': 627.2677559334043, 'average_number_of_words_per_sentence': 29.40625, 'complex_word_count': 620, 'word_count': 2823, 'syllable_per_word': 1.957137796670209, 'average_word_length': 5.913212894084308}
# Sentiment: {'polarity_score': 9.616000000000001, 'positive_score': 10.81, 'negative_score': 1.1940000000000002, 'subjectivity_score': 0.841}
# Total Personal Pronouns: 102
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# Complexity: {'average_sentence_length': 33.47142857142857, 'percentage_of_complex_words': 27.571489543320528, 'fog_index': 711.127248338516, 'average_number_of_words_per_sentence': 33.47142857142857, 'complex_word_count': 646, 'word_count': 2343, 'syllable_per_word': 2.084933845497226, 'average_word_length': 6.306871532223645}
# Sentiment: {'polarity_score': 5.006, 'positive_score': 6.334, 'negative_score': 1.328, 'subjectivity_score': 0.856}
# Total Personal Pronouns: 98
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# Complexity: {'average_sentence_length': 35.166666666666664, 'percentage_of_complex_words': 25.764756570443776, 'fog_index': 744.1433290248456, 'average_number_of_words_per_sentence': 35.166666666666664, 'complex_word_count': 598, 'word_count': 2321, 'syllable_per_word': 2.040499784575614, 'average_word_length': 6.207669108143042}
# Sentiment: {'polarity_score': -0.9880000000000001, 'positive_score': 3.5279999999999996, 'negative_score': 4.516000000000001, 'subjectivity_score': 0.807}
# Total Personal Pronouns: 89
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# Complexity: {'average_sentence_length': 33.80357142857143, 'percentage_of_complex_words': 24.141574220813524, 'fog_index': 715.6805146781376, 'average_number_of_words_per_sentence': 33.80357142857143, 'complex_word_count': 457, 'word_count': 1893, 'syllable_per_word': 1.9804543053354464, 'average_word_length': 6.108821975699947}
# Sentiment: {'polarity_score': 5.8340000000000005, 'positive_score': 6.123000000000001, 'negative_score': 0.289, 'subjectivity_score': 0.88}
# Total Personal Pronouns: 94
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/
# Complexity: {'average_sentence_length': 30.676190476190477, 'percentage_of_complex_words': 27.13443030114871, 'fog_index': 654.6042193344274, 'average_number_of_words_per_sentence': 30.676190476190477, 'complex_word_count': 874, 'word_count': 3221, 'syllable_per_word': 2.054020490530891, 'average_word_length': 6.276622167028873}
# Sentiment: {'polarity_score': 10.371000000000002, 'positive_score': 10.986000000000002, 'negative_score': 0.6150000000000001, 'subjectivity_score': 0.847}
# Total Personal Pronouns: 109
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/
# Complexity: {'average_sentence_length': 28.293478260869566, 'percentage_of_complex_words': 21.552055320783712, 'fog_index': 604.6017972573453, 'average_number_of_words_per_sentence': 28.293478260869566, 'complex_word_count': 561, 'word_count': 2603, 'syllable_per_word': 1.9366116019976949, 'average_word_length': 5.9154821359969265}
# Sentiment: {'polarity_score': -3.139, 'positive_score': 4.423, 'negative_score': 7.562, 'subjectivity_score': 0.813}
# Total Personal Pronouns: 109
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/
# Complexity: {'average_sentence_length': 32.26984126984127, 'percentage_of_complex_words': 26.168224299065418, 'fog_index': 686.9413408911687, 'average_number_of_words_per_sentence': 32.26984126984127, 'complex_word_count': 532, 'word_count': 2033, 'syllable_per_word': 2.0772257747171667, 'average_word_length': 6.315297589768814}
# Sentiment: {'polarity_score': 3.7479999999999998, 'positive_score': 4.362, 'negative_score': 0.6139999999999999, 'subjectivity_score': 0.875}
# Total Personal Pronouns: 84
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/
# Complexity: {'average_sentence_length': 30.45205479452055, 'percentage_of_complex_words': 26.99055330634278, 'fog_index': 650.8224724086297, 'average_number_of_words_per_sentence': 30.45205479452055, 'complex_word_count': 600, 'word_count': 2223, 'syllable_per_word': 2.0890688259109313, 'average_word_length': 6.284750337381916}
# Sentiment: {'polarity_score': 3.157, 'positive_score': 5.922999999999999, 'negative_score': 2.7659999999999996, 'subjectivity_score': 0.81}
# Total Personal Pronouns: 91
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/
# Complexity: {'average_sentence_length': 20.575875486381324, 'percentage_of_complex_words': 22.371406959152797, 'fog_index': 450.27696509827706, 'average_number_of_words_per_sentence': 20.575875486381324, 'complex_word_count': 1183, 'word_count': 5288, 'syllable_per_word': 1.9379727685325265, 'average_word_length': 5.851361573373676}
# Sentiment: {'polarity_score': 6.016999999999999, 'positive_score': 24.445999999999998, 'negative_score': 18.428999999999995, 'subjectivity_score': 0.727}
# Total Personal Pronouns: 203
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/
# Complexity: {'average_sentence_length': 32.588235294117645, 'percentage_of_complex_words': 25.920577617328522, 'fog_index': 692.5517094924613, 'average_number_of_words_per_sentence': 32.588235294117645, 'complex_word_count': 718, 'word_count': 2770, 'syllable_per_word': 2.0393501805054153, 'average_word_length': 6.2111913357400725}
# Sentiment: {'polarity_score': 6.835000000000001, 'positive_score': 8.082, 'negative_score': 1.247, 'subjectivity_score': 0.85}
# Total Personal Pronouns: 85
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/
# Complexity: {'average_sentence_length': 30.65979381443299, 'percentage_of_complex_words': 23.70544720914593, 'fog_index': 654.4601668064811, 'average_number_of_words_per_sentence': 30.65979381443299, 'complex_word_count': 705, 'word_count': 2974, 'syllable_per_word': 2.063214525891056, 'average_word_length': 6.136852723604573}
# Sentiment: {'polarity_score': 12.870999999999995, 'positive_score': 13.627999999999997, 'negative_score': 0.757, 'subjectivity_score': 0.858}
# Total Personal Pronouns: 119
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/
# Complexity: {'average_sentence_length': 44.75, 'percentage_of_complex_words': 23.798882681564244, 'fog_index': 935.3575418994413, 'average_number_of_words_per_sentence': 44.75, 'complex_word_count': 426, 'word_count': 1790, 'syllable_per_word': 2.017877094972067, 'average_word_length': 6.099441340782123}
# Sentiment: {'polarity_score': 5.344000000000002, 'positive_score': 5.348000000000002, 'negative_score': 0.004, 'subjectivity_score': 0.854}
# Total Personal Pronouns: 93
#
# ==================================================
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/
# Complexity: {'average_sentence_length': 28.270588235294117, 'percentage_of_complex_words': 22.43029546400333, 'fog_index': 603.9968666617709, 'average_number_of_words_per_sentence': 28.270588235294117, 'complex_word_count': 539, 'word_count': 2403, 'syllable_per_word': 1.9292550977944236, 'average_word_length': 5.969621306699959}
# Sentiment: {'polarity_score': 4.812, 'positive_score': 7.293000000000001, 'negative_score': 2.481, 'subjectivity_score': 0.857}
# Total Personal Pronouns: 102
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/
# Complexity: {'average_sentence_length': 32.71052631578947, 'percentage_of_complex_words': 23.169750603378922, 'fog_index': 693.8243638057332, 'average_number_of_words_per_sentence': 32.71052631578947, 'complex_word_count': 576, 'word_count': 2486, 'syllable_per_word': 1.9806918744971842, 'average_word_length': 6.063153660498793}
# Sentiment: {'polarity_score': 8.239999999999998, 'positive_score': 9.287999999999998, 'negative_score': 1.048, 'subjectivity_score': 0.798}
# Total Personal Pronouns: 105
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/
# Complexity: {'average_sentence_length': 32.723684210526315, 'percentage_of_complex_words': 22.919179734620023, 'fog_index': 693.9348824413265, 'average_number_of_words_per_sentence': 32.723684210526315, 'complex_word_count': 570, 'word_count': 2487, 'syllable_per_word': 1.973059911540008, 'average_word_length': 6.051065540812224}
# Sentiment: {'polarity_score': 8.311999999999998, 'positive_score': 9.344, 'negative_score': 1.032, 'subjectivity_score': 0.791}
# Total Personal Pronouns: 104
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/
# Complexity: {'average_sentence_length': 30.05, 'percentage_of_complex_words': 23.87687188019967, 'fog_index': 640.3843594009984, 'average_number_of_words_per_sentence': 30.05, 'complex_word_count': 574, 'word_count': 2404, 'syllable_per_word': 1.9692179700499168, 'average_word_length': 6.068635607321132}
# Sentiment: {'polarity_score': 7.734000000000001, 'positive_score': 8.274000000000001, 'negative_score': 0.54, 'subjectivity_score': 0.862}
# Total Personal Pronouns: 102
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/
# Complexity: {'average_sentence_length': 40.39655172413793, 'percentage_of_complex_words': 24.71190781049936, 'fog_index': 847.4103345254389, 'average_number_of_words_per_sentence': 40.39655172413793, 'complex_word_count': 579, 'word_count': 2343, 'syllable_per_word': 1.9739650021340163, 'average_word_length': 6.060179257362356}
# Sentiment: {'polarity_score': 5.3519999999999985, 'positive_score': 6.402999999999999, 'negative_score': 1.051, 'subjectivity_score': 0.882}
# Total Personal Pronouns: 85
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/
# Complexity: {'average_sentence_length': 27.392857142857142, 'percentage_of_complex_words': 23.011734028683183, 'fog_index': 586.7424101322407, 'average_number_of_words_per_sentence': 27.392857142857142, 'complex_word_count': 706, 'word_count': 3068, 'syllable_per_word': 1.9442633637548892, 'average_word_length': 5.916558018252934}
# Sentiment: {'polarity_score': 14.395999999999995, 'positive_score': 14.491999999999994, 'negative_score': 0.09600000000000002, 'subjectivity_score': 0.868}
# Total Personal Pronouns: 167
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/
# Complexity: {'average_sentence_length': 39.28888888888889, 'percentage_of_complex_words': 20.418552036199095, 'fog_index': 824.375062845651, 'average_number_of_words_per_sentence': 39.28888888888889, 'complex_word_count': 361, 'word_count': 1768, 'syllable_per_word': 1.9298642533936652, 'average_word_length': 5.980769230769231}
# Sentiment: {'polarity_score': 7.888000000000003, 'positive_score': 8.020000000000003, 'negative_score': 0.132, 'subjectivity_score': 0.833}
# Total Personal Pronouns: 109
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/
# Complexity: {'average_sentence_length': 34.22727272727273, 'percentage_of_complex_words': 23.727312970340858, 'fog_index': 724.6251358203549, 'average_number_of_words_per_sentence': 34.22727272727273, 'complex_word_count': 536, 'word_count': 2259, 'syllable_per_word': 2.00398406374502, 'average_word_length': 6.098273572377158}
# Sentiment: {'polarity_score': 1.5039999999999998, 'positive_score': 4.1209999999999996, 'negative_score': 2.617, 'subjectivity_score': 0.828}
# Total Personal Pronouns: 95
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/
# Complexity: {'average_sentence_length': 35.52272727272727, 'percentage_of_complex_words': 21.177223288547665, 'fog_index': 749.4692607456524, 'average_number_of_words_per_sentence': 35.52272727272727, 'complex_word_count': 331, 'word_count': 1563, 'syllable_per_word': 1.9507357645553423, 'average_word_length': 6.019193857965451}
# Sentiment: {'polarity_score': 1.8479999999999994, 'positive_score': 2.853, 'negative_score': 1.0050000000000001, 'subjectivity_score': 0.87}
# Total Personal Pronouns: 83
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/
# Complexity: {'average_sentence_length': 33.46835443037975, 'percentage_of_complex_words': 18.494704992435704, 'fog_index': 707.4457572914074, 'average_number_of_words_per_sentence': 33.46835443037975, 'complex_word_count': 489, 'word_count': 2644, 'syllable_per_word': 1.9039334341906202, 'average_word_length': 5.829425113464448}
# Sentiment: {'polarity_score': 6.260999999999999, 'positive_score': 7.335, 'negative_score': 1.0740000000000003, 'subjectivity_score': 0.846}
# Total Personal Pronouns: 108
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/
# Complexity: {'average_sentence_length': 49.75, 'percentage_of_complex_words': 22.166387493020657, 'fog_index': 1033.8944723618092, 'average_number_of_words_per_sentence': 49.75, 'complex_word_count': 397, 'word_count': 1791, 'syllable_per_word': 1.9447236180904524, 'average_word_length': 6.00390843104411}
# Sentiment: {'polarity_score': 3.676, 'positive_score': 4.0489999999999995, 'negative_score': 0.373, 'subjectivity_score': 0.863}
# Total Personal Pronouns: 83
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/
# Complexity: {'average_sentence_length': 53.69767441860465, 'percentage_of_complex_words': 18.839324382849718, 'fog_index': 1110.4021674539467, 'average_number_of_words_per_sentence': 53.69767441860465, 'complex_word_count': 435, 'word_count': 2309, 'syllable_per_word': 1.8224339540926808, 'average_word_length': 5.694239930705933}
# Sentiment: {'polarity_score': 3.2179999999999995, 'positive_score': 3.4520000000000004, 'negative_score': 0.23399999999999999, 'subjectivity_score': 0.883}
# Total Personal Pronouns: 106
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/
# Complexity: {'average_sentence_length': 37.80701754385965, 'percentage_of_complex_words': 21.25290023201856, 'fog_index': 794.3120446126918, 'average_number_of_words_per_sentence': 37.80701754385965, 'complex_word_count': 458, 'word_count': 2155, 'syllable_per_word': 1.908584686774942, 'average_word_length': 5.873781902552204}
# Sentiment: {'polarity_score': 3.4569999999999994, 'positive_score': 5.134, 'negative_score': 1.677, 'subjectivity_score': 0.884}
# Total Personal Pronouns: 89
#
# ==================================================
# URL: https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/
# Complexity: {'average_sentence_length': 36.929577464788736, 'percentage_of_complex_words': 17.658276125095345, 'fog_index': 774.7700389982919, 'average_number_of_words_per_sentence': 36.929577464788736, 'complex_word_count': 463, 'word_count': 2622, 'syllable_per_word': 1.8089244851258581, 'average_word_length': 5.592295957284516}
# Sentiment: {'polarity_score': 4.068999999999998, 'positive_score': 5.6850000000000005, 'negative_score': 1.616, 'subjectivity_score': 0.85}
# Total Personal Pronouns: 127
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/
# Complexity: {'average_sentence_length': 41.8421052631579, 'percentage_of_complex_words': 22.51572327044025, 'fog_index': 875.3242855566589, 'average_number_of_words_per_sentence': 41.8421052631579, 'complex_word_count': 537, 'word_count': 2385, 'syllable_per_word': 1.9241090146750524, 'average_word_length': 5.940041928721174}
# Sentiment: {'polarity_score': 3.6959999999999993, 'positive_score': 4.624, 'negative_score': 0.928, 'subjectivity_score': 0.847}
# Total Personal Pronouns: 101
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# Complexity: {'average_sentence_length': 34.619565217391305, 'percentage_of_complex_words': 24.615384615384617, 'fog_index': 732.5796873933521, 'average_number_of_words_per_sentence': 34.619565217391305, 'complex_word_count': 784, 'word_count': 3185, 'syllable_per_word': 2.009419152276295, 'average_word_length': 6.114285714285714}
# Sentiment: {'polarity_score': 7.956000000000001, 'positive_score': 8.859, 'negative_score': 0.903, 'subjectivity_score': 0.837}
# Total Personal Pronouns: 104
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# Complexity: {'average_sentence_length': 27.8989898989899, 'percentage_of_complex_words': 19.044170890658943, 'fog_index': 594.3447509124555, 'average_number_of_words_per_sentence': 27.8989898989899, 'complex_word_count': 526, 'word_count': 2762, 'syllable_per_word': 1.8182476466328747, 'average_word_length': 5.593772628530051}
# Sentiment: {'polarity_score': 5.8640000000000025, 'positive_score': 9.554999999999996, 'negative_score': 3.6910000000000007, 'subjectivity_score': 0.816}
# Total Personal Pronouns: 129
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# Complexity: {'average_sentence_length': 29.62135922330097, 'percentage_of_complex_words': 22.877745001638807, 'fog_index': 631.7454407754262, 'average_number_of_words_per_sentence': 29.62135922330097, 'complex_word_count': 698, 'word_count': 3051, 'syllable_per_word': 1.9659128154703376, 'average_word_length': 5.952146837102589}
# Sentiment: {'polarity_score': 4.858, 'positive_score': 7.761000000000001, 'negative_score': 2.903000000000001, 'subjectivity_score': 0.888}
# Total Personal Pronouns: 105
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# Complexity: {'average_sentence_length': 26.455357142857142, 'percentage_of_complex_words': 18.056024299696254, 'fog_index': 566.3059278723302, 'average_number_of_words_per_sentence': 26.455357142857142, 'complex_word_count': 535, 'word_count': 2963, 'syllable_per_word': 1.8599392507593655, 'average_word_length': 5.665204184947688}
# Sentiment: {'polarity_score': 8.497999999999994, 'positive_score': 11.122999999999996, 'negative_score': 2.6250000000000004, 'subjectivity_score': 0.841}
# Total Personal Pronouns: 128
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# Complexity: {'average_sentence_length': 32.05154639175258, 'percentage_of_complex_words': 20.16725635252493, 'fog_index': 678.3226615114748, 'average_number_of_words_per_sentence': 32.05154639175258, 'complex_word_count': 627, 'word_count': 3109, 'syllable_per_word': 1.8645866838211644, 'average_word_length': 5.759408169829527}
# Sentiment: {'polarity_score': 5.9110000000000005, 'positive_score': 8.427, 'negative_score': 2.516, 'subjectivity_score': 0.832}
# Total Personal Pronouns: 144
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# Complexity: {'average_sentence_length': 31.214285714285715, 'percentage_of_complex_words': 19.260106788710907, 'fog_index': 661.5015800370493, 'average_number_of_words_per_sentence': 31.214285714285715, 'complex_word_count': 505, 'word_count': 2622, 'syllable_per_word': 1.860793287566743, 'average_word_length': 5.713196033562166}
# Sentiment: {'polarity_score': 6.33, 'positive_score': 7.26, 'negative_score': 0.9299999999999999, 'subjectivity_score': 0.839}
# Total Personal Pronouns: 149
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# Complexity: {'average_sentence_length': 31.158730158730158, 'percentage_of_complex_words': 21.599592460519613, 'fog_index': 661.37124097389, 'average_number_of_words_per_sentence': 31.158730158730158, 'complex_word_count': 424, 'word_count': 1963, 'syllable_per_word': 1.9098318899643403, 'average_word_length': 5.889454915944982}
# Sentiment: {'polarity_score': 4.307, 'positive_score': 4.968, 'negative_score': 0.6609999999999999, 'subjectivity_score': 0.888}
# Total Personal Pronouns: 91
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Complexity: {'average_sentence_length': 63.11764705882353, 'percentage_of_complex_words': 21.528424976700837, 'fog_index': 1301.309138753358, 'average_number_of_words_per_sentence': 63.11764705882353, 'complex_word_count': 231, 'word_count': 1073, 'syllable_per_word': 1.9478098788443616, 'average_word_length': 6.037278657968313}
# Sentiment: {'polarity_score': 1.119, 'positive_score': 1.226, 'negative_score': 0.107, 'subjectivity_score': 0.904}
# Total Personal Pronouns: 74
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# Complexity: {'average_sentence_length': 34.517857142857146, 'percentage_of_complex_words': 20.17589239524056, 'fog_index': 728.1119281649545, 'average_number_of_words_per_sentence': 34.517857142857146, 'complex_word_count': 390, 'word_count': 1933, 'syllable_per_word': 1.8877392653905847, 'average_word_length': 5.799793067770305}
# Sentiment: {'polarity_score': 4.354, 'positive_score': 4.877000000000001, 'negative_score': 0.523, 'subjectivity_score': 0.839}
# Total Personal Pronouns: 114
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# Complexity: {'average_sentence_length': 35.63636363636363, 'percentage_of_complex_words': 19.529478458049887, 'fog_index': 750.4937126365699, 'average_number_of_words_per_sentence': 35.63636363636363, 'complex_word_count': 689, 'word_count': 3528, 'syllable_per_word': 1.8883219954648527, 'average_word_length': 5.659863945578231}
# Sentiment: {'polarity_score': 7.415000000000002, 'positive_score': 9.053999999999998, 'negative_score': 1.6390000000000002, 'subjectivity_score': 0.83}
# Total Personal Pronouns: 150
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/
# Complexity: {'average_sentence_length': 28.80327868852459, 'percentage_of_complex_words': 18.69664200341491, 'fog_index': 612.8441736566615, 'average_number_of_words_per_sentence': 28.80327868852459, 'complex_word_count': 657, 'word_count': 3514, 'syllable_per_word': 1.8389299943084803, 'average_word_length': 5.539840637450199}
# Sentiment: {'polarity_score': 3.5100000000000002, 'positive_score': 9.059, 'negative_score': 5.549000000000001, 'subjectivity_score': 0.816}
# Total Personal Pronouns: 228
#
# ==================================================
# URL: https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/
# Complexity: {'average_sentence_length': 31.986842105263158, 'percentage_of_complex_words': 24.269847799259566, 'fog_index': 680.1317413236918, 'average_number_of_words_per_sentence': 31.986842105263158, 'complex_word_count': 590, 'word_count': 2431, 'syllable_per_word': 2.0197449609214315, 'average_word_length': 6.108185931715344}
# Sentiment: {'polarity_score': 6.039000000000002, 'positive_score': 7.2890000000000015, 'negative_score': 1.25, 'subjectivity_score': 0.845}
# Total Personal Pronouns: 107
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/
# Complexity: {'average_sentence_length': 25.36, 'percentage_of_complex_words': 19.63722397476341, 'fog_index': 544.2583596214512, 'average_number_of_words_per_sentence': 25.36, 'complex_word_count': 498, 'word_count': 2536, 'syllable_per_word': 1.8529179810725551, 'average_word_length': 5.693611987381703}
# Sentiment: {'polarity_score': 7.712999999999998, 'positive_score': 10.884999999999998, 'negative_score': 3.1719999999999997, 'subjectivity_score': 0.842}
# Total Personal Pronouns: 92
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/
# Complexity: {'average_sentence_length': 36.333333333333336, 'percentage_of_complex_words': 19.503907577302073, 'fog_index': 764.6551138294258, 'average_number_of_words_per_sentence': 36.333333333333336, 'complex_word_count': 574, 'word_count': 2943, 'syllable_per_word': 1.8994223581379546, 'average_word_length': 5.7679238871899425}
# Sentiment: {'polarity_score': 6.3900000000000015, 'positive_score': 7.068000000000001, 'negative_score': 0.678, 'subjectivity_score': 0.847}
# Total Personal Pronouns: 155
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# Complexity: {'average_sentence_length': 30.77777777777778, 'percentage_of_complex_words': 20.282244830981295, 'fog_index': 653.1794479086898, 'average_number_of_words_per_sentence': 30.77777777777778, 'complex_word_count': 618, 'word_count': 3047, 'syllable_per_word': 1.8811946176567116, 'average_word_length': 5.742369543813587}
# Sentiment: {'polarity_score': 10.057999999999996, 'positive_score': 10.424999999999997, 'negative_score': 0.367, 'subjectivity_score': 0.84}
# Total Personal Pronouns: 122
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/
# Complexity: {'average_sentence_length': 43.921052631578945, 'percentage_of_complex_words': 23.7866986219293, 'fog_index': 918.5289016429632, 'average_number_of_words_per_sentence': 43.921052631578945, 'complex_word_count': 397, 'word_count': 1669, 'syllable_per_word': 2.005392450569203, 'average_word_length': 6.097064110245656}
# Sentiment: {'polarity_score': 3.828, 'positive_score': 3.842, 'negative_score': 0.014000000000000002, 'subjectivity_score': 0.879}
# Total Personal Pronouns: 80
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/
# Complexity: {'average_sentence_length': 103.44827586206897, 'percentage_of_complex_words': 18.633333333333333, 'fog_index': 2106.9521839080458, 'average_number_of_words_per_sentence': 103.44827586206897, 'complex_word_count': 559, 'word_count': 3000, 'syllable_per_word': 1.8993333333333333, 'average_word_length': 5.788}
# Sentiment: {'polarity_score': 1.581, 'positive_score': 1.807, 'negative_score': 0.22599999999999998, 'subjectivity_score': 0.832}
# Total Personal Pronouns: 140
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/
# Complexity: {'average_sentence_length': 30.549295774647888, 'percentage_of_complex_words': 22.268326417704014, 'fog_index': 649.7503230540458, 'average_number_of_words_per_sentence': 30.549295774647888, 'complex_word_count': 483, 'word_count': 2169, 'syllable_per_word': 1.938220378054403, 'average_word_length': 5.890272014753343}
# Sentiment: {'polarity_score': 7.045, 'positive_score': 7.362, 'negative_score': 0.317, 'subjectivity_score': 0.873}
# Total Personal Pronouns: 112
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/evolution-of-advertising-industry/
# Complexity: {'average_sentence_length': 32.40677966101695, 'percentage_of_complex_words': 23.797071129707113, 'fog_index': 687.1104886178287, 'average_number_of_words_per_sentence': 32.40677966101695, 'complex_word_count': 455, 'word_count': 1912, 'syllable_per_word': 1.948744769874477, 'average_word_length': 6.0219665271966525}
# Sentiment: {'polarity_score': 4.776000000000001, 'positive_score': 5.010000000000001, 'negative_score': 0.234, 'subjectivity_score': 0.891}
# Total Personal Pronouns: 81
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/
# Complexity: {'average_sentence_length': 49.2, 'percentage_of_complex_words': 23.712737127371277, 'fog_index': 1024.0135501355014, 'average_number_of_words_per_sentence': 49.2, 'complex_word_count': 350, 'word_count': 1476, 'syllable_per_word': 2.0006775067750677, 'average_word_length': 6.157181571815718}
# Sentiment: {'polarity_score': 2.515, 'positive_score': 2.7420000000000004, 'negative_score': 0.227, 'subjectivity_score': 0.869}
# Total Personal Pronouns: 81
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Complexity: {'average_sentence_length': 63.11764705882353, 'percentage_of_complex_words': 21.528424976700837, 'fog_index': 1301.309138753358, 'average_number_of_words_per_sentence': 63.11764705882353, 'complex_word_count': 231, 'word_count': 1073, 'syllable_per_word': 1.9478098788443616, 'average_word_length': 6.037278657968313}
# Sentiment: {'polarity_score': 1.119, 'positive_score': 1.226, 'negative_score': 0.107, 'subjectivity_score': 0.904}
# Total Personal Pronouns: 74
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/
# Complexity: {'average_sentence_length': 36.54794520547945, 'percentage_of_complex_words': 20.314842578710646, 'fog_index': 769.1598036598139, 'average_number_of_words_per_sentence': 36.54794520547945, 'complex_word_count': 542, 'word_count': 2668, 'syllable_per_word': 1.9100449775112445, 'average_word_length': 5.8343328335832085}
# Sentiment: {'polarity_score': -0.03600000000000003, 'positive_score': 3.195, 'negative_score': 3.2310000000000003, 'subjectivity_score': 0.851}
# Total Personal Pronouns: 95
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/
# Complexity: {'average_sentence_length': 41.46808510638298, 'percentage_of_complex_words': 21.29297075423294, 'fog_index': 867.8019278844579, 'average_number_of_words_per_sentence': 41.46808510638298, 'complex_word_count': 415, 'word_count': 1949, 'syllable_per_word': 1.9220112878399178, 'average_word_length': 5.931759876859928}
# Sentiment: {'polarity_score': 3.1470000000000002, 'positive_score': 3.4989999999999997, 'negative_score': 0.352, 'subjectivity_score': 0.896}
# Total Personal Pronouns: 89
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/
# Complexity: {'average_sentence_length': 25.689922480620154, 'percentage_of_complex_words': 19.070609535304765, 'fog_index': 550.5998980131272, 'average_number_of_words_per_sentence': 25.689922480620154, 'complex_word_count': 632, 'word_count': 3314, 'syllable_per_word': 1.84007242003621, 'average_word_length': 5.647857573928787}
# Sentiment: {'polarity_score': 9.431999999999997, 'positive_score': 13.095999999999997, 'negative_score': 3.6639999999999993, 'subjectivity_score': 0.815}
# Total Personal Pronouns: 130
#
# ==================================================
# URL: https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/
# Complexity: {'average_sentence_length': 29.92063492063492, 'percentage_of_complex_words': 21.220159151193634, 'fog_index': 637.6806029219823, 'average_number_of_words_per_sentence': 29.92063492063492, 'complex_word_count': 400, 'word_count': 1885, 'syllable_per_word': 1.9633952254641909, 'average_word_length': 5.959681697612732}
# Sentiment: {'polarity_score': 6.342999999999999, 'positive_score': 6.701999999999999, 'negative_score': 0.359, 'subjectivity_score': 0.853}
# Total Personal Pronouns: 94
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/
# Complexity: {'average_sentence_length': 44.2, 'percentage_of_complex_words': 20.232708468002585, 'fog_index': 923.224305106658, 'average_number_of_words_per_sentence': 44.2, 'complex_word_count': 313, 'word_count': 1547, 'syllable_per_word': 1.9612152553329023, 'average_word_length': 6.009696186166774}
# Sentiment: {'polarity_score': 3.283, 'positive_score': 3.2869999999999995, 'negative_score': 0.004, 'subjectivity_score': 0.89}
# Total Personal Pronouns: 84
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/
# Complexity: {'average_sentence_length': 35.11764705882353, 'percentage_of_complex_words': 18.634840871021776, 'fog_index': 739.5388708247119, 'average_number_of_words_per_sentence': 35.11764705882353, 'complex_word_count': 445, 'word_count': 2388, 'syllable_per_word': 1.8592964824120604, 'average_word_length': 5.705192629815746}
# Sentiment: {'polarity_score': 4.960000000000002, 'positive_score': 5.107000000000002, 'negative_score': 0.14700000000000002, 'subjectivity_score': 0.881}
# Total Personal Pronouns: 112
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/
# Complexity: {'average_sentence_length': 43.829268292682926, 'percentage_of_complex_words': 22.760155815247636, 'fog_index': 916.6632734774762, 'average_number_of_words_per_sentence': 43.829268292682926, 'complex_word_count': 409, 'word_count': 1797, 'syllable_per_word': 2.0038953811908735, 'average_word_length': 6.089037284362827}
# Sentiment: {'polarity_score': 4.483, 'positive_score': 4.659, 'negative_score': 0.176, 'subjectivity_score': 0.855}
# Total Personal Pronouns: 75
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/
# Complexity: {'average_sentence_length': 33.69565217391305, 'percentage_of_complex_words': 21.806451612903228, 'fog_index': 713.3582047685835, 'average_number_of_words_per_sentence': 33.69565217391305, 'complex_word_count': 338, 'word_count': 1550, 'syllable_per_word': 1.972258064516129, 'average_word_length': 6.014838709677419}
# Sentiment: {'polarity_score': 4.084, 'positive_score': 4.777, 'negative_score': 0.6930000000000001, 'subjectivity_score': 0.847}
# Total Personal Pronouns: 85
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-we-forecast-future-technologies/
# Complexity: {'average_sentence_length': 42.096774193548384, 'percentage_of_complex_words': 22.911877394636015, 'fog_index': 882.0427635644545, 'average_number_of_words_per_sentence': 42.096774193548384, 'complex_word_count': 299, 'word_count': 1305, 'syllable_per_word': 2.0053639846743296, 'average_word_length': 6.132567049808429}
# Sentiment: {'polarity_score': 2.061, 'positive_score': 2.162, 'negative_score': 0.101, 'subjectivity_score': 0.873}
# Total Personal Pronouns: 77
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/
# Complexity: {'average_sentence_length': 27.77027027027027, 'percentage_of_complex_words': 19.464720194647203, 'fog_index': 592.6024856973762, 'average_number_of_words_per_sentence': 27.77027027027027, 'complex_word_count': 400, 'word_count': 2055, 'syllable_per_word': 1.85985401459854, 'average_word_length': 5.697323600973236}
# Sentiment: {'polarity_score': -1.2999999999999996, 'positive_score': 4.966, 'negative_score': 6.266000000000001, 'subjectivity_score': 0.794}
# Total Personal Pronouns: 165
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/
# Complexity: {'average_sentence_length': 48.407407407407405, 'percentage_of_complex_words': 22.417750573833207, 'fog_index': 1008.5766102751567, 'average_number_of_words_per_sentence': 48.407407407407405, 'complex_word_count': 293, 'word_count': 1307, 'syllable_per_word': 2.021423106350421, 'average_word_length': 6.179035960214231}
# Sentiment: {'polarity_score': 2.551, 'positive_score': 2.955, 'negative_score': 0.404, 'subjectivity_score': 0.846}
# Total Personal Pronouns: 76
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/
# Complexity: {'average_sentence_length': 33.054054054054056, 'percentage_of_complex_words': 24.693376941946035, 'fog_index': 701.6861505823076, 'average_number_of_words_per_sentence': 33.054054054054056, 'complex_word_count': 604, 'word_count': 2446, 'syllable_per_word': 2.0302534750613246, 'average_word_length': 6.135731807031889}
# Sentiment: {'polarity_score': 5.625000000000003, 'positive_score': 6.618000000000003, 'negative_score': 0.9929999999999999, 'subjectivity_score': 0.85}
# Total Personal Pronouns: 106
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/
# Complexity: {'average_sentence_length': 44.02564102564103, 'percentage_of_complex_words': 21.025043680838674, 'fog_index': 919.0567925570839, 'average_number_of_words_per_sentence': 44.02564102564103, 'complex_word_count': 361, 'word_count': 1717, 'syllable_per_word': 1.9271986022131624, 'average_word_length': 5.957483983692487}
# Sentiment: {'polarity_score': -0.8540000000000006, 'positive_score': 2.0429999999999997, 'negative_score': 2.897, 'subjectivity_score': 0.81}
# Total Personal Pronouns: 89
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/
# Complexity: {'average_sentence_length': 31.760563380281692, 'percentage_of_complex_words': 18.226164079822617, 'fog_index': 673.17135629743, 'average_number_of_words_per_sentence': 31.760563380281692, 'complex_word_count': 411, 'word_count': 2255, 'syllable_per_word': 1.8980044345898004, 'average_word_length': 5.835033259423503}
# Sentiment: {'polarity_score': 1.2050000000000003, 'positive_score': 4.557, 'negative_score': 3.3520000000000008, 'subjectivity_score': 0.854}
# Total Personal Pronouns: 121
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/
# Complexity: {'average_sentence_length': 33.204301075268816, 'percentage_of_complex_words': 21.9559585492228, 'fog_index': 702.7518246141847, 'average_number_of_words_per_sentence': 33.204301075268816, 'complex_word_count': 678, 'word_count': 3088, 'syllable_per_word': 1.9332901554404145, 'average_word_length': 5.865932642487047}
# Sentiment: {'polarity_score': 2.063, 'positive_score': 4.286, 'negative_score': 2.2229999999999994, 'subjectivity_score': 0.897}
# Total Personal Pronouns: 128
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/
# Complexity: {'average_sentence_length': 33.943820224719104, 'percentage_of_complex_words': 17.04733531943065, 'fog_index': 715.5728626208303, 'average_number_of_words_per_sentence': 33.943820224719104, 'complex_word_count': 515, 'word_count': 3021, 'syllable_per_word': 1.8348229063224097, 'average_word_length': 5.647136709698775}
# Sentiment: {'polarity_score': 6.104000000000001, 'positive_score': 6.788, 'negative_score': 0.684, 'subjectivity_score': 0.858}
# Total Personal Pronouns: 128
#
# ==================================================
# URL: https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/
# Complexity: {'average_sentence_length': 27.92, 'percentage_of_complex_words': 17.29942693409742, 'fog_index': 594.3813753581662, 'average_number_of_words_per_sentence': 27.92, 'complex_word_count': 483, 'word_count': 2792, 'syllable_per_word': 1.7990687679083095, 'average_word_length': 5.593839541547278}
# Sentiment: {'polarity_score': 3.789000000000001, 'positive_score': 7.1560000000000015, 'negative_score': 3.3669999999999995, 'subjectivity_score': 0.857}
# Total Personal Pronouns: 126
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/
# Complexity: {'average_sentence_length': 26.443037974683545, 'percentage_of_complex_words': 18.525610339875538, 'fog_index': 565.3471166023354, 'average_number_of_words_per_sentence': 26.443037974683545, 'complex_word_count': 387, 'word_count': 2089, 'syllable_per_word': 1.8243178554332216, 'average_word_length': 5.6395404499760655}
# Sentiment: {'polarity_score': 5.275000000000001, 'positive_score': 7.892, 'negative_score': 2.6169999999999995, 'subjectivity_score': 0.853}
# Total Personal Pronouns: 148
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/
# Complexity: {'average_sentence_length': 32.38095238095238, 'percentage_of_complex_words': 17.058823529411764, 'fog_index': 682.795518207283, 'average_number_of_words_per_sentence': 32.38095238095238, 'complex_word_count': 464, 'word_count': 2720, 'syllable_per_word': 1.7588235294117647, 'average_word_length': 5.464705882352941}
# Sentiment: {'polarity_score': 4.766000000000001, 'positive_score': 6.391999999999999, 'negative_score': 1.626, 'subjectivity_score': 0.867}
# Total Personal Pronouns: 153
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/
# Complexity: {'average_sentence_length': 50.5, 'percentage_of_complex_words': 21.16336633663366, 'fog_index': 1048.6881188118812, 'average_number_of_words_per_sentence': 50.5, 'complex_word_count': 342, 'word_count': 1616, 'syllable_per_word': 1.9344059405940595, 'average_word_length': 5.878712871287129}
# Sentiment: {'polarity_score': 4.148000000000001, 'positive_score': 4.189, 'negative_score': 0.04100000000000001, 'subjectivity_score': 0.859}
# Total Personal Pronouns: 101
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/
# Complexity: {'average_sentence_length': 34.15294117647059, 'percentage_of_complex_words': 20.461591457113332, 'fog_index': 721.2675730988228, 'average_number_of_words_per_sentence': 34.15294117647059, 'complex_word_count': 594, 'word_count': 2903, 'syllable_per_word': 1.9104374784705478, 'average_word_length': 5.802962452635205}
# Sentiment: {'polarity_score': 7.335000000000001, 'positive_score': 7.699999999999999, 'negative_score': 0.36499999999999994, 'subjectivity_score': 0.859}
# Total Personal Pronouns: 100
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/
# Complexity: {'average_sentence_length': 24.57608695652174, 'percentage_of_complex_words': 17.735515258735074, 'fog_index': 528.8326635001827, 'average_number_of_words_per_sentence': 24.57608695652174, 'complex_word_count': 401, 'word_count': 2261, 'syllable_per_word': 1.865546218487395, 'average_word_length': 5.5811587793011945}
# Sentiment: {'polarity_score': 1.4179999999999995, 'positive_score': 9.258999999999997, 'negative_score': 7.841, 'subjectivity_score': 0.748}
# Total Personal Pronouns: 174
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/
# Complexity: {'average_sentence_length': 25.05263157894737, 'percentage_of_complex_words': 16.512605042016805, 'fog_index': 536.548429898275, 'average_number_of_words_per_sentence': 25.05263157894737, 'complex_word_count': 393, 'word_count': 2380, 'syllable_per_word': 1.7747899159663865, 'average_word_length': 5.5323529411764705}
# Sentiment: {'polarity_score': 6.201000000000002, 'positive_score': 9.359, 'negative_score': 3.158, 'subjectivity_score': 0.82}
# Total Personal Pronouns: 178
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/
# Complexity: {'average_sentence_length': 37.96825396825397, 'percentage_of_complex_words': 18.520066889632105, 'fog_index': 796.4721027764506, 'average_number_of_words_per_sentence': 37.96825396825397, 'complex_word_count': 443, 'word_count': 2392, 'syllable_per_word': 1.855351170568562, 'average_word_length': 5.845317725752508}
# Sentiment: {'polarity_score': 2.0709999999999993, 'positive_score': 4.9239999999999995, 'negative_score': 2.853, 'subjectivity_score': 0.799}
# Total Personal Pronouns: 92
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/
# Complexity: {'average_sentence_length': 28.822916666666668, 'percentage_of_complex_words': 21.10589085652331, 'fog_index': 614.3622003373088, 'average_number_of_words_per_sentence': 28.822916666666668, 'complex_word_count': 584, 'word_count': 2767, 'syllable_per_word': 1.8951933501987712, 'average_word_length': 5.782797253342971}
# Sentiment: {'polarity_score': 5.614, 'positive_score': 7.181, 'negative_score': 1.5670000000000002, 'subjectivity_score': 0.84}
# Total Personal Pronouns: 112
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/
# ...
# Sentiment: {'polarity_score': 3.5719999999999996, 'positive_score': 5.404999999999999, 'negative_score': 1.833, 'subjectivity_score': 0.826}
# Total Personal Pronouns: 138
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/
# Complexity: {'average_sentence_length': 51.8421052631579, 'percentage_of_complex_words': 20.101522842639593, 'fog_index': 1075.1771306438684, 'average_number_of_words_per_sentence': 51.8421052631579, 'complex_word_count': 396, 'word_count': 1970, 'syllable_per_word': 1.916751269035533, 'average_word_length': 5.960913705583756}
# Sentiment: {'polarity_score': 2.3690000000000007, 'positive_score': 2.955, 'negative_score': 0.586, 'subjectivity_score': 0.872}
# Total Personal Pronouns: 80
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/
# Complexity: {'average_sentence_length': 47.745098039215684, 'percentage_of_complex_words': 22.012320328542096, 'fog_index': 993.7274227966342, 'average_number_of_words_per_sentence': 47.745098039215684, 'complex_word_count': 536, 'word_count': 2435, 'syllable_per_word': 1.9412731006160164, 'average_word_length': 6.014373716632443}
# Sentiment: {'polarity_score': 3.554000000000001, 'positive_score': 4.11, 'negative_score': 0.556, 'subjectivity_score': 0.874}
# Total Personal Pronouns: 82
#
# ==================================================
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/
# Complexity: {'average_sentence_length': 33.62222222222222, 'percentage_of_complex_words': 19.993390614672833, 'fog_index': 710.1575971212455, 'average_number_of_words_per_sentence': 33.62222222222222, 'complex_word_count': 605, 'word_count': 3026, 'syllable_per_word': 1.8856576338400528, 'average_word_length': 5.776272306675479}
# Sentiment: {'polarity_score': -0.07800000000000015, 'positive_score': 3.9890000000000008, 'negative_score': 4.066999999999999, 'subjectivity_score': 0.841}
# Total Personal Pronouns: 115
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/
# Complexity: {'average_sentence_length': 23.72897196261682, 'percentage_of_complex_words': 17.15242221346987, 'fog_index': 508.26986855521164, 'average_number_of_words_per_sentence': 23.72897196261682, 'complex_word_count': 871, 'word_count': 5078, 'syllable_per_word': 1.6845214651437574, 'average_word_length': 5.4515557306026}
# Sentiment: {'polarity_score': 1.3870000000000018, 'positive_score': 11.62, 'negative_score': 10.233, 'subjectivity_score': 0.837}
# Total Personal Pronouns: 95
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/
# Complexity: {'average_sentence_length': 29.5, 'percentage_of_complex_words': 20.664928292046937, 'fog_index': 627.7053455019558, 'average_number_of_words_per_sentence': 29.5, 'complex_word_count': 634, 'word_count': 3068, 'syllable_per_word': 1.8852672750977835, 'average_word_length': 5.789765319426336}
# Sentiment: {'polarity_score': 4.833000000000002, 'positive_score': 6.4410000000000025, 'negative_score': 1.608, 'subjectivity_score': 0.892}
# Total Personal Pronouns: 130
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/
# Complexity: {'average_sentence_length': 34.888888888888886, 'percentage_of_complex_words': 23.248407643312103, 'fog_index': 737.6291578202406, 'average_number_of_words_per_sentence': 34.888888888888886, 'complex_word_count': 657, 'word_count': 2826, 'syllable_per_word': 1.9925690021231421, 'average_word_length': 6.018400566171267}
# Sentiment: {'polarity_score': 1.2609999999999995, 'positive_score': 5.0569999999999995, 'negative_score': 3.7960000000000003, 'subjectivity_score': 0.863}
# Total Personal Pronouns: 87
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/human-rights-outlook/
# Complexity: {'average_sentence_length': 53.68, 'percentage_of_complex_words': 21.833084947839048, 'fog_index': 1112.8399403874814, 'average_number_of_words_per_sentence': 53.68, 'complex_word_count': 293, 'word_count': 1342, 'syllable_per_word': 1.9619970193740686, 'average_word_length': 6.055141579731743}
# Sentiment: {'polarity_score': 2.3169999999999997, 'positive_score': 2.326, 'negative_score': 0.008999999999999998, 'subjectivity_score': 0.881}
# Total Personal Pronouns: 86
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/
# Complexity: {'average_sentence_length': 36.28125, 'percentage_of_complex_words': 18.69078380706288, 'fog_index': 762.2572136089578, 'average_number_of_words_per_sentence': 36.28125, 'complex_word_count': 434, 'word_count': 2322, 'syllable_per_word': 1.8316106804478898, 'average_word_length': 5.640826873385013}
# Sentiment: {'polarity_score': 6.153000000000001, 'positive_score': 6.3420000000000005, 'negative_score': 0.189, 'subjectivity_score': 0.865}
# Total Personal Pronouns: 119
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/
# Complexity: {'average_sentence_length': 22.611510791366907, 'percentage_of_complex_words': 19.121858097359212, 'fog_index': 489.0739956555277, 'average_number_of_words_per_sentence': 22.611510791366907, 'complex_word_count': 601, 'word_count': 3143, 'syllable_per_word': 1.8421889914094813, 'average_word_length': 5.693286668787782}
# Sentiment: {'polarity_score': 5.079999999999999, 'positive_score': 8.453999999999999, 'negative_score': 3.374, 'subjectivity_score': 0.857}
# Total Personal Pronouns: 130
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/
# Complexity: {'average_sentence_length': 27.973214285714285, 'percentage_of_complex_words': 19.502074688796682, 'fog_index': 596.1575509552688, 'average_number_of_words_per_sentence': 27.973214285714285, 'complex_word_count': 611, 'word_count': 3133, 'syllable_per_word': 1.834663262049154, 'average_word_length': 5.674752633258858}
# Sentiment: {'polarity_score': 13.008, 'positive_score': 13.625999999999998, 'negative_score': 0.618, 'subjectivity_score': 0.838}
# Total Personal Pronouns: 151
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/
# Complexity: {'average_sentence_length': 38.083333333333336, 'percentage_of_complex_words': 19.38730853391685, 'fog_index': 799.5660102115245, 'average_number_of_words_per_sentence': 38.083333333333336, 'complex_word_count': 443, 'word_count': 2285, 'syllable_per_word': 1.8949671772428884, 'average_word_length': 5.859518599562363}
# Sentiment: {'polarity_score': 1.6390000000000002, 'positive_score': 3.763000000000001, 'negative_score': 2.124, 'subjectivity_score': 0.855}
# Total Personal Pronouns: 100
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/
# Complexity: {'average_sentence_length': 39.44871794871795, 'percentage_of_complex_words': 22.131946701332467, 'fog_index': 826.9204103230754, 'average_number_of_words_per_sentence': 39.44871794871795, 'complex_word_count': 681, 'word_count': 3077, 'syllable_per_word': 1.8973025674358142, 'average_word_length': 5.909652258693533}
# Sentiment: {'polarity_score': 1.06, 'positive_score': 3.496, 'negative_score': 2.436, 'subjectivity_score': 0.867}
# Total Personal Pronouns: 81
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/
# Complexity: {'average_sentence_length': 32.23529411764706, 'percentage_of_complex_words': 20.392335766423358, 'fog_index': 682.5708458565908, 'average_number_of_words_per_sentence': 32.23529411764706, 'complex_word_count': 447, 'word_count': 2192, 'syllable_per_word': 1.8932481751824817, 'average_word_length': 5.822536496350365}
# Sentiment: {'polarity_score': 2.0100000000000002, 'positive_score': 4.957000000000001, 'negative_score': 2.9470000000000005, 'subjectivity_score': 0.835}
# Total Personal Pronouns: 95
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/
# Complexity: {'average_sentence_length': 27.175824175824175, 'percentage_of_complex_words': 18.762636473918317, 'fog_index': 580.435205716241, 'average_number_of_words_per_sentence': 27.175824175824175, 'complex_word_count': 464, 'word_count': 2473, 'syllable_per_word': 1.845936109987869, 'average_word_length': 5.676506267691064}
# Sentiment: {'polarity_score': 2.899000000000001, 'positive_score': 7.729, 'negative_score': 4.829999999999999, 'subjectivity_score': 0.811}
# Total Personal Pronouns: 132
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/
# Complexity: {'average_sentence_length': 44.07692307692308, 'percentage_of_complex_words': 20.11343804537522, 'fog_index': 919.7845348368909, 'average_number_of_words_per_sentence': 44.07692307692308, 'complex_word_count': 461, 'word_count': 2292, 'syllable_per_word': 1.912303664921466, 'average_word_length': 5.9057591623036645}
# Sentiment: {'polarity_score': 2.957, 'positive_score': 3.9380000000000006, 'negative_score': 0.9810000000000001, 'subjectivity_score': 0.849}
# Total Personal Pronouns: 107
#
# ==================================================
# URL: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/
# Complexity: {'average_sentence_length': 35.026666666666664, 'percentage_of_complex_words': 20.74609821088694, 'fog_index': 737.8534703717802, 'average_number_of_words_per_sentence': 35.026666666666664, 'complex_word_count': 545, 'word_count': 2627, 'syllable_per_word': 1.866006851922345, 'average_word_length': 5.833650551960411}
# Sentiment: {'polarity_score': -2.1380000000000003, 'positive_score': 3.2790000000000004, 'negative_score': 5.417000000000001, 'subjectivity_score': 0.836}
# Total Personal Pronouns: 92
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/travel-and-tourism-outlook/
# Complexity: {'average_sentence_length': 52.0, 'percentage_of_complex_words': 20.76923076923077, 'fog_index': 1078.8, 'average_number_of_words_per_sentence': 52.0, 'complex_word_count': 270, 'word_count': 1300, 'syllable_per_word': 1.94, 'average_word_length': 5.986153846153846}
# Sentiment: {'polarity_score': 2.2199999999999998, 'positive_score': 2.4570000000000003, 'negative_score': 0.237, 'subjectivity_score': 0.878}
# Total Personal Pronouns: 80
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/
# Complexity: {'average_sentence_length': 29.860759493670887, 'percentage_of_complex_words': 18.397626112759642, 'fog_index': 633.857835062057, 'average_number_of_words_per_sentence': 29.860759493670887, 'complex_word_count': 434, 'word_count': 2359, 'syllable_per_word': 1.8321322594319627, 'average_word_length': 5.6604493429419245}
# Sentiment: {'polarity_score': -1.7819999999999996, 'positive_score': 4.484, 'negative_score': 6.265999999999999, 'subjectivity_score': 0.821}
# Total Personal Pronouns: 145
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/
# Complexity: {'average_sentence_length': 33.96296296296296, 'percentage_of_complex_words': 21.046892039258452, 'fog_index': 716.8056060422473, 'average_number_of_words_per_sentence': 33.96296296296296, 'complex_word_count': 386, 'word_count': 1834, 'syllable_per_word': 1.8773173391494002, 'average_word_length': 5.865321701199564}
# Sentiment: {'polarity_score': 1.924, 'positive_score': 4.1530000000000005, 'negative_score': 2.229, 'subjectivity_score': 0.863}
# Total Personal Pronouns: 85
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/
# Complexity: {'average_sentence_length': 35.196969696969695, 'percentage_of_complex_words': 23.590185105467068, 'fog_index': 743.1300956182575, 'average_number_of_words_per_sentence': 35.196969696969695, 'complex_word_count': 548, 'word_count': 2323, 'syllable_per_word': 1.9595350839431769, 'average_word_length': 6.036160137752906}
# Sentiment: {'polarity_score': -0.9939999999999999, 'positive_score': 3.948, 'negative_score': 4.941999999999999, 'subjectivity_score': 0.829}
# Total Personal Pronouns: 74
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/
# Complexity: {'average_sentence_length': 40.87719298245614, 'percentage_of_complex_words': 18.11158798283262, 'fog_index': 854.2563060010542, 'average_number_of_words_per_sentence': 40.87719298245614, 'complex_word_count': 422, 'word_count': 2330, 'syllable_per_word': 1.8356223175965665, 'average_word_length': 5.669098712446352}
# Sentiment: {'polarity_score': 1.169, 'positive_score': 2.9969999999999994, 'negative_score': 1.8279999999999998, 'subjectivity_score': 0.846}
# Total Personal Pronouns: 115
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/
# Complexity: {'average_sentence_length': 57.111111111111114, 'percentage_of_complex_words': 23.411154345006484, 'fog_index': 1182.001729355815, 'average_number_of_words_per_sentence': 57.111111111111114, 'complex_word_count': 361, 'word_count': 1542, 'syllable_per_word': 1.9889753566796369, 'average_word_length': 6.162775616083009}
# Sentiment: {'polarity_score': 2.094, 'positive_score': 2.121, 'negative_score': 0.027000000000000007, 'subjectivity_score': 0.88}
# Total Personal Pronouns: 75
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# Complexity: {'average_sentence_length': 37.06, 'percentage_of_complex_words': 19.104155423637344, 'fog_index': 778.6096060442526, 'average_number_of_words_per_sentence': 37.06, 'complex_word_count': 354, 'word_count': 1853, 'syllable_per_word': 1.8704803022126282, 'average_word_length': 5.826227738801943}
# Sentiment: {'polarity_score': 4.734999999999999, 'positive_score': 4.968999999999999, 'negative_score': 0.23399999999999999, 'subjectivity_score': 0.869}
# Total Personal Pronouns: 91
#
# ==================================================
#
# URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/
# Complexity: {'average_sentence_length': 46.372549019607845, 'percentage_of_complex_words': 21.3953488372093, 'fog_index': 965.4552087219665, 'average_number_of_words_per_sentence': 46.372549019607845, 'complex_word_count': 506, 'word_count': 2365, 'syllable_per_word': 1.9002114164904862, 'average_word_length': 5.896405919661734}
# Sentiment: {'polarity_score': 0.5699999999999998, 'positive_score': 2.5359999999999996, 'negative_score': 1.966, 'subjectivity_score': 0.83}
# Total Personal Pronouns: 89
#
# ==================================================
